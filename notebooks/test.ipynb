# %%
from langchain_community.document_loaders import TextLoader

# %%
document = TextLoader("nvda_news_1.txt").load()

# %%
document[0].metadata
# Out:
# {'source': 'nvda_news_1.txt'}

# %%
# !pip install unstructured libmagic python-magic python-magic-bin
# Out:
# Collecting unstructured
#   Downloading unstructured-0.17.2-py3-none-any.whl.metadata (24 kB)
# Collecting libmagic
#   Downloading libmagic-1.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting python-magic-bin
#   Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl.metadata (710 bytes)
# Collecting chardet (from unstructured)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-5.4.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured) (2.32.3)
# Collecting beautifulsoup4 (from unstructured)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured) (2.2.5)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.13.0-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured) (4.13.2)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.34.0-py3-none-any.whl.metadata (21 kB)
# Collecting wrapt (from unstructured)
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting tqdm (from unstructured)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured) (7.0.0)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Collecting webencodings (from html5lib->unstructured)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting click (from nltk->unstructured)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting joblib (from nltk->unstructured)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk->unstructured)
#   Downloading regex-2024.11.6-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: colorama in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from requests->unstructured) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from requests->unstructured) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from requests->unstructured) (2025.4.26)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting eval-type-backport>=0.2.0 (from unstructured-client->unstructured)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured-client->unstructured) (2.11.4)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from unstructured-client->unstructured) (0.4.0)
# Collecting cffi>=1.12 (from cryptography>=3.1->unstructured-client->unstructured)
#   Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: anyio in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\phoen\anaconda3\envs\llms\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Downloading unstructured-0.17.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.6 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl (409 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 590.6/590.6 kB 4.2 MB/s eta 0:00:00
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-5.4.0-cp310-cp310-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 4.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 3.9 MB/s eta 0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    --------------------------- ------------ 1.0/1.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.2 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp310-cp310-win_amd64.whl (274 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.13.0-cp310-cp310-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.8 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading unstructured_client-0.34.0-py3-none-any.whl (189 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.2 MB 5.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.8/3.2 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.2 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 4.0 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Building wheels for collected packages: libmagic, langdetect
#   Building wheel for libmagic (setup.py): started
#   Building wheel for libmagic (setup.py): finished with status 'done'
#   Created wheel for libmagic: filename=libmagic-1.0-py3-none-any.whl size=4324 sha256=18a16c6b976ffc61eea6542d8b3004c8b9708936caca71e5a6b0471a2d40a454
#   Stored in directory: c:\users\phoen\appdata\local\pip\cache\wheels\31\ce\d8\099fbd4dbfa5da5596a39eee8a17d2e1bcc29006c07d3563b7
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993364 sha256=33e556a2f89f2e24784c2e7d41f8264770f49d0ef75dec5aac29428cf25fb15a
#   Stored in directory: c:\users\phoen\appdata\local\pip\cache\wheels\95\03\7d\59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built libmagic langdetect
# Installing collected packages: webencodings, python-magic-bin, libmagic, filetype, wrapt, tqdm, soupsieve, regex, rapidfuzz, python-magic, python-iso639, pypdf, pycparser, olefile, lxml, langdetect, joblib, html5lib, eval-type-backport, emoji, click, chardet, backoff, aiofiles, python-oxmsg, nltk, cffi, beautifulsoup4, cryptography, unstructured-client, unstructured
#
#    ----- ----------------------------------  4/31 [wrapt]
#    ------- --------------------------------  6/31 [soupsieve]
#    --------- ------------------------------  7/31 [regex]
#    ---------- -----------------------------  8/31 [rapidfuzz]
#    ----------- ----------------------------  9/31 [python-magic]
#    -------------- ------------------------- 11/31 [pypdf]
#    -------------- ------------------------- 11/31 [pypdf]
#    --------------- ------------------------ 12/31 [pycparser]
#    ---------------- ----------------------- 13/31 [olefile]
#    ------------------ --------------------- 14/31 [lxml]
#    ------------------ --------------------- 14/31 [lxml]
#    ------------------- -------------------- 15/31 [langdetect]
#    -------------------- ------------------- 16/31 [joblib]
#    -------------------- ------------------- 16/31 [joblib]
#    -------------------- ------------------- 16/31 [joblib]
#    --------------------- ------------------ 17/31 [html5lib]
#    ----------------------- ---------------- 18/31 [eval-type-backport]
#    ------------------------- -------------- 20/31 [click]
#    --------------------------- ------------ 21/31 [chardet]
#    --------------------------- ------------ 21/31 [chardet]
#    --------------------------- ------------ 21/31 [chardet]
#    ------------------------------ --------- 24/31 [python-oxmsg]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    -------------------------------- ------- 25/31 [nltk]
#    --------------------------------- ------ 26/31 [cffi]
#    ---------------------------------- ----- 27/31 [beautifulsoup4]
#    ------------------------------------ --- 28/31 [cryptography]
#    ------------------------------------ --- 28/31 [cryptography]
#    ------------------------------------ --- 28/31 [cryptography]
#    ------------------------------------- -- 29/31 [unstructured-client]
#    ------------------------------------- -- 29/31 [unstructured-client]
#    ------------------------------------- -- 29/31 [unstructured-client]
#    ------------------------------------- -- 29/31 [unstructured-client]
#    ------------------------------------- -- 29/31 [unstructured-client]
#    ------------------------------------- -- 29/31 [unstructured-client]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    -------------------------------------- - 30/31 [unstructured]
#    ---------------------------------------- 31/31 [unstructured]
#
# Successfully installed aiofiles-24.1.0 backoff-2.2.1 beautifulsoup4-4.13.4 cffi-1.17.1 chardet-5.2.0 click-8.1.8 cryptography-44.0.2 emoji-2.14.1 eval-type-backport-0.2.2 filetype-1.2.0 html5lib-1.1 joblib-1.4.2 langdetect-1.0.9 libmagic-1.0 lxml-5.4.0 nltk-3.9.1 olefile-0.47 pycparser-2.22 pypdf-5.4.0 python-iso639-2025.2.18 python-magic-0.4.27 python-magic-bin-0.4.14 python-oxmsg-0.0.2 rapidfuzz-3.13.0 regex-2024.11.6 soupsieve-2.7 tqdm-4.67.1 unstructured-0.17.2 unstructured-client-0.34.0 webencodings-0.5.1 wrapt-1.17.2
#   DEPRECATION: Building 'libmagic' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'libmagic'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
from langchain_community.document_loaders import UnstructuredURLLoader


loader = UnstructuredURLLoader(urls=[
    "https://coffeeandjunk.com/articles/",
    "https://www.toptal.com/management-consultants/business-consultants/ai-in-finance"
])

data = loader.load()

# %%
data[0]
# Out:
# Document(metadata={'source': 'https://coffeeandjunk.com/articles/'}, page_content='This page shares my best articles to read on topics like learning, decision-making, wealth, creativity, productivity, and more.\n\nThe central question that drives my work is, “How can we go to bed smarter than when we woke up?” I do this by “mastering the best of what other people have already figured out.” After all it’s much easier to benefit from lessons that other people have already paid the price for than making all the mistakes yourself.\n\nYou’ll find interesting articles to read on topics like making better decisions, accelerating learning, and more. You’ll also find articles explaining how to use mental models, how to read better, and finding your purpose.